# %%
# 24.08.30
import pandas as pd
import numpy as np
import seaborn as sns

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.info()
titanic.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB
# ...

# %%
# 타이타닉호의 승객 데이터 개수 확인 완료
# 평균 연령 확인 완료

# %%
titanic['sex'].value_counts() # 남성 탑승자가 많다.
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
titanic['survived'].value_counts()
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
titanic['age'][titanic.sex == 'female'].mean()
# Out:
# 27.915708812260537

# %%
round(titanic['age'][titanic.sex == 'male'].mean(),1)
# Out:
# 30.7

# %%
titanic.age
# null 값을 어떻게 처리할 것인가?
# 1. 전체 평균을 입력
# 2. 성별에 따라서 입력하는 방법
# 3. 좌석에 따른 평균 연령
# 4. 탑승 비용에 따라(구간 분류) 평균 연령 입력
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
titanic.pclass.value_counts()
# Out:
# pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
titanic.age[titanic.age.isnull()] = titanic.age.mean()
# 연령 평균내서
# Out:
# C:\Users\wag19\AppData\Local\Temp\ipykernel_1672\2137585586.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titanic.age[titanic.age.isnull()] = titanic.age.mean()

# %%
titanic
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          891 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
bins = [0, 20, 35, 50, 70, 100]
labels = ['미성년자', '청년', '중년', '장년', '노년']
titanic['age_labels'] = pd.cut(titanic.age, bins, labels=labels, right=False)
titanic
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town alive  alone age_lables  \
# ...

# %%
titanic['category'] = titanic.apply(lambda x: '미성년자' if x.age<20 else x.age_labels + x.sex, axis=1)
titanic
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town alive  alone age_lables  \
# ...

# %%
titanic[['sex','survived']].value_counts()
# 살아남은 사람을 예측하는 것이 빠름
# Out:
# sex     survived
# male    0           468
# female  1           233
# male    1           109
# female  0            81
# Name: count, dtype: int64

# %%
titanic[['sex','age_labels','survived']].value_counts().sort_index()
# 여성 전체적으로 생존율 높음
# 남성 전체적으로 생존율 낮음. 그나마 미성년자
# Out:
# sex     age_labels  survived
# female  미성년자        0            22
#                     1            53
#         청년          0            43
#                     1           115
#         중년          0            14
#                     1            45
#         장년          0             2
#                     1            20
# male    미성년자        0            63
#                     1            26
#         청년          0           280
#                     1            54
#         중년          0            80
#                     1            22
#         장년          0            39
#                     1             6
#         노년          0             6
#                     1             1
# Name: count, dtype: int64

# %%
titanic['fare'].describe()
# titanic[['sex','fare','survived']].value_counts()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: fare, dtype: float64

# %%
# titanic['fare'].sort_values().reset_index()
bins = [0, 7.9, 14.45, 31, 512]
labels = ['q0', 'q1', 'q2', 'q3']
titanic['fare_labels'] = pd.cut(titanic.fare, bins, labels=labels, right=False)
titanic
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town alive  alone age_lables  \
# ...

# %%
titanic[['sex','fare_labels','survived']].value_counts().sort_index()
# 남성의 경우 비용이 많이 들었을수록 생존률 증가
# Out:
# sex     fare_labels  survived
# female  q0           0            13
#                      1            30
#         q1           0            20
#                      1            42
#         q2           0            32
#                      1            65
#         q3           0            16
#                      1            95
# male    q0           0           166
#                      1            14
#         q1           0           130
#                      1            25
#         q2           0            94
#                      1            35
#         q3           0            78
#                      1            33
# Name: count, dtype: int64

# %%
# titanic[['sex','embark_town','survived']].value_counts().sort_index()
titanic[['embark_town','survived']].value_counts().sort_index()
# Cherbourg 가 유독 생존률이 높음
# Out:
# embark_town  survived
# Cherbourg    0            75
#              1            93
# Queenstown   0            47
#              1            30
# Southampton  0           427
#              1           217
# Name: count, dtype: int64

# %% [markdown]
# @@@@@@@@@@@@@@@@@@@

# %%
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
df = pd.read_csv('data/titanic/train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# ...

# %%
df = df.drop('PassengerId',axis=1)
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
# 구분짓기
def get_nickname(x):
    nickname = x.split('.')[0]
    nickname = nickname.split()[-1]
    return nickname

df['title'] = df.Name.apply(get_nickname)
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# ...

# %%
df.drop('Name', axis=1, inplace=True)
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0           0       3    male  22.0      1      0         A/5 21171   7.2500
# 1           1       1  female  38.0      1      0          PC 17599  71.2833
# 2           1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3           1       1  female  35.0      1      0            113803  53.1000
# 4           0       3    male  35.0      0      0            373450   8.0500
# ..        ...     ...     ...   ...    ...    ...               ...      ...
# 886         0       2    male  27.0      0      0            211536  13.0000
# 887         1       1  female  19.0      0      0            112053  30.0000
# 888         0       3  female   NaN      1      2        W./C. 6607  23.4500
# 889         1       1    male  26.0      0      0            111369  30.0000
# 890         0       3    male  32.0      0      0            370376   7.7500
#
#     Cabin Embarked title
# ...

# %%
df.title.value_counts()[df.title.value_counts() < 10].index
# Out:
# Index(['Dr', 'Rev', 'Mlle', 'Major', 'Col', 'Countess', 'Capt', 'Ms', 'Sir',
#        'Lady', 'Mme', 'Don', 'Jonkheer'],
#       dtype='object', name='title')

# %%
df.title.value_counts().index
# Out:
# Index(['Mr', 'Miss', 'Mrs', 'Master', 'Dr', 'Rev', 'Mlle', 'Major', 'Col',
#        'Countess', 'Capt', 'Ms', 'Sir', 'Lady', 'Mme', 'Don', 'Jonkheer'],
#       dtype='object', name='title')

# %%
title_mapping = {'Mr':1, 'Miss':2, 'Mrs':3, 'Master':4, 'Dr':0, 'Rev':0, 'Mlle':0, 'Major':0, 'Col':0,
       'Countess':0, 'Capt':0, 'Ms':0, 'Sir':0, 'Lady':0, 'Mme':0, 'Don':0, 'Jonkheer':0}

# %%
df['title'] = df['title'].map(title_mapping)
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0           0       3    male  22.0      1      0         A/5 21171   7.2500
# 1           1       1  female  38.0      1      0          PC 17599  71.2833
# 2           1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3           1       1  female  35.0      1      0            113803  53.1000
# 4           0       3    male  35.0      0      0            373450   8.0500
# ..        ...     ...     ...   ...    ...    ...               ...      ...
# 886         0       2    male  27.0      0      0            211536  13.0000
# 887         1       1  female  19.0      0      0            112053  30.0000
# 888         0       3  female   NaN      1      2        W./C. 6607  23.4500
# 889         1       1    male  26.0      0      0            111369  30.0000
# 890         0       3    male  32.0      0      0            370376   7.7500
#
#     Cabin Embarked  title
# ...

# %%
# 'Mr':1, 'Miss':2, 'Mrs':3, 'Master':4
df[['title','Survived']].value_counts().sort_index()
# Out:
# title  Survived
# 0      0            15
#        1            12
# 1      0           436
#        1            81
# 2      0            55
#        1           127
# 3      0            26
#        1            99
# 4      0            17
#        1            23
# Name: count, dtype: int64

# %%
df.drop('Ticket', axis=1, inplace=True)
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked  \
# 0           0       3    male  22.0      1      0   7.2500   NaN        S
# 1           1       1  female  38.0      1      0  71.2833   C85        C
# 2           1       3  female  26.0      0      0   7.9250   NaN        S
# 3           1       1  female  35.0      1      0  53.1000  C123        S
# 4           0       3    male  35.0      0      0   8.0500   NaN        S
# ..        ...     ...     ...   ...    ...    ...      ...   ...      ...
# 886         0       2    male  27.0      0      0  13.0000   NaN        S
# 887         1       1  female  19.0      0      0  30.0000   B42        S
# 888         0       3  female   NaN      1      2  23.4500   NaN        S
# 889         1       1    male  26.0      0      0  30.0000  C148        C
# 890         0       3    male  32.0      0      0   7.7500   NaN        Q
#
#      title
# 0        1
# 1        3
# 2        2
# 3        3
# 4        1
# ...

# %%
df.drop('Cabin', axis=1, inplace=True)
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked  title
# 0           0       3    male  22.0      1      0   7.2500        S      1
# 1           1       1  female  38.0      1      0  71.2833        C      3
# 2           1       3  female  26.0      0      0   7.9250        S      2
# 3           1       1  female  35.0      1      0  53.1000        S      3
# 4           0       3    male  35.0      0      0   8.0500        S      1
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 886         0       2    male  27.0      0      0  13.0000        S      0
# 887         1       1  female  19.0      0      0  30.0000        S      2
# 888         0       3  female   NaN      1      2  23.4500        S      2
# 889         1       1    male  26.0      0      0  30.0000        C      1
# 890         0       3    male  32.0      0      0   7.7500        Q      1
#
# [891 rows x 9 columns]

# %%
df['family_size']= df.SibSp + df.Parch + 1
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked  title  \
# 0           0       3    male  22.0      1      0   7.2500        S      1
# 1           1       1  female  38.0      1      0  71.2833        C      3
# 2           1       3  female  26.0      0      0   7.9250        S      2
# 3           1       1  female  35.0      1      0  53.1000        S      3
# 4           0       3    male  35.0      0      0   8.0500        S      1
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 886         0       2    male  27.0      0      0  13.0000        S      0
# 887         1       1  female  19.0      0      0  30.0000        S      2
# 888         0       3  female   NaN      1      2  23.4500        S      2
# 889         1       1    male  26.0      0      0  30.0000        C      1
# 890         0       3    male  32.0      0      0   7.7500        Q      1
#
#      family_size
# 0              2
# 1              2
# ...

# %%
sex_mapping = {'male' : 0, 'female' : 1}
df['Sex'] = df['Sex'].map(sex_mapping)
df
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked  title  \
# 0           0       3    0  22.0      1      0   7.2500        S      1
# 1           1       1    1  38.0      1      0  71.2833        C      3
# 2           1       3    1  26.0      0      0   7.9250        S      2
# 3           1       1    1  35.0      1      0  53.1000        S      3
# 4           0       3    0  35.0      0      0   8.0500        S      1
# ..        ...     ...  ...   ...    ...    ...      ...      ...    ...
# 886         0       2    0  27.0      0      0  13.0000        S      0
# 887         1       1    1  19.0      0      0  30.0000        S      2
# 888         0       3    1   NaN      1      2  23.4500        S      2
# 889         1       1    0  26.0      0      0  30.0000        C      1
# 890         0       3    0  32.0      0      0   7.7500        Q      1
#
#      family_size
# 0              2
# 1              2
# 2              1
# 3              2
# ...

# %%
df[['family_size','Survived']].value_counts().sort_index()
# Out:
# family_size  Survived
# 1            0           374
#              1           163
# 2            0            72
#              1            89
# 3            0            43
#              1            59
# 4            0             8
#              1            21
# 5            0            12
#              1             3
# 6            0            19
#              1             3
# 7            0             8
#              1             4
# 8            0             6
# 11           0             7
# Name: count, dtype: int64

# %%
df.Embarked.value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df['Embarked'] = df.Embarked.fillna('S')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Survived     891 non-null    int64
#  1   Pclass       891 non-null    int64
#  2   Sex          891 non-null    int64
#  3   Age          714 non-null    float64
#  4   SibSp        891 non-null    int64
#  5   Parch        891 non-null    int64
#  6   Fare         891 non-null    float64
#  7   Embarked     891 non-null    object
#  8   title        891 non-null    int64
#  9   family_size  891 non-null    int64
# dtypes: float64(2), int64(7), object(1)
# memory usage: 69.7+ KB

# %%
df.Age.fillna(df.Age.mean(), inplace=True)
df
# Out:
# C:\Users\wag19\AppData\Local\Temp\ipykernel_1672\1738542242.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Age.fillna(df.Age.mean(), inplace=True)
#      Survived  Pclass  Sex        Age  SibSp  Parch     Fare Embarked  title  \
# 0           0       3    0  22.000000      1      0   7.2500        S      1
# 1           1       1    1  38.000000      1      0  71.2833        C      3
# 2           1       3    1  26.000000      0      0   7.9250        S      2
# ...

# %%
embark_mapping = {'S':0, 'C': 1, 'Q':2}
df['Embarked']=df.Embarked.map(embark_mapping)
df
# Out:
#      Survived  Pclass  Sex        Age  SibSp  Parch     Fare  Embarked  title  \
# 0           0       3    0  22.000000      1      0   7.2500         0      1
# 1           1       1    1  38.000000      1      0  71.2833         1      3
# 2           1       3    1  26.000000      0      0   7.9250         0      2
# 3           1       1    1  35.000000      1      0  53.1000         0      3
# 4           0       3    0  35.000000      0      0   8.0500         0      1
# ..        ...     ...  ...        ...    ...    ...      ...       ...    ...
# 886         0       2    0  27.000000      0      0  13.0000         0      0
# 887         1       1    1  19.000000      0      0  30.0000         0      2
# 888         0       3    1  29.699118      1      2  23.4500         0      2
# 889         1       1    0  26.000000      0      0  30.0000         1      1
# 890         0       3    0  32.000000      0      0   7.7500         2      1
#
#      family_size
# ...

# %% [markdown]
# @@@@@@@@@@@@@@@@@@

# %%
# scikit-learn : 머신러닝 라이브러리(cpu로 동작)
# tensorflow, pytorch : 딥러닝 라이브러리
# !pip install scikit-learn
# Out:
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.8 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.8 kB ? eta -:--:--
#      -------------------------------- ----- 51.2/60.8 kB 435.7 kB/s eta 0:00:01
#      -------------------------------------- 60.8/60.8 kB 463.7 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.0 MB 6.8 MB/s eta 0:00:02
#    - -------------------------------------- 0.3/11.0 MB 3.1 MB/s eta 0:00:04
#    - -------------------------------------- 0.5/11.0 MB 4.2 MB/s eta 0:00:03
#    -- ------------------------------------- 0.7/11.0 MB 3.5 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.3/11.0 MB 5.4 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.4/11.0 MB 5.0 MB/s eta 0:00:02
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier # 종류 예측 모델(분류 모델) != 선형 회귀(회귀 모델)
clf = KNeighborsClassifier(n_neighbors=7) # 인접한 데이터의 참고 갯수
# KNN : 근접한 데이터를 보고 가장 많은 결과의 데이터를 예측 결과로 판단.
# decision tree, random forest, svm, linear regression, lgbm

# %%
# 교차 검증
from sklearn.model_selection import KFold, cross_val_score

# %%
k_fold = KFold(n_splits=10,shuffle=True, random_state=2024) # 교차검증 10회 진행

# %%
train = df.drop('Survived', axis=1)
train
# Out:
#      Pclass  Sex        Age  SibSp  Parch     Fare  Embarked  title  \
# 0         3    0  22.000000      1      0   7.2500         0      1
# 1         1    1  38.000000      1      0  71.2833         1      3
# 2         3    1  26.000000      0      0   7.9250         0      2
# 3         1    1  35.000000      1      0  53.1000         0      3
# 4         3    0  35.000000      0      0   8.0500         0      1
# ..      ...  ...        ...    ...    ...      ...       ...    ...
# 886       2    0  27.000000      0      0  13.0000         0      0
# 887       1    1  19.000000      0      0  30.0000         0      2
# 888       3    1  29.699118      1      2  23.4500         0      2
# 889       1    0  26.000000      0      0  30.0000         1      1
# 890       3    0  32.000000      0      0   7.7500         2      1
#
#      family_size
# 0              2
# 1              2
# 2              1
# 3              2
# 4              1
# ..           ...
# 886            1
# ...

# %%
target = df.Survived
target
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
score = cross_val_score(clf, train, target, cv=k_fold, n_jobs=1, scoring='accuracy')
print(score)
# Out:
# [0.76666667 0.73033708 0.73033708 0.75280899 0.74157303 0.78651685
#  0.74157303 0.7752809  0.75280899 0.74157303]

# %%
score.mean()
# Out:
# 0.7519475655430712
