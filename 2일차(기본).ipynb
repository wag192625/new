# %%
x = 'python \n java' # \n 엔터 기능
print(x)
# Out:
# python
#  java

# %%
x = 'Life is \'too \'short' # \뒤에 글자를 붙이면 기능을 제외하고 인식
print(x)
# Out:
# Life is 'too 'short

# %%
x = 'Life is "too" short' # 같은 따옴표 안에 있을 경우
x = "Life is 'too' short"
print(x)
# Out:
# Life is 'too' short

# %%
# replace = 지정한 글자, 변경할 문자, 횟수 / 보통 한꺼번에 바꿀 때
text = 'python, java, c, c++'
# text.replace('c', 'R')
# text.replace(text[text.find('c')],'R')
text.replace('c','R',1)
# Out:
# 'python, java, R, c++'

# %%
# 타입
text = '1'
type(text)

text = 1
type(text)
# Out:
# int

# %%
for i in range(4, 10 ,2): # 시작 숫자, 종료 숫자, 횟수
  print(i)
# Out:
# 4
# 6
# 8

# %%
text = ['python', 'java' ,'c', 'c++']

for i in text:
  for x in i:
    print(x)
# Out:
# p
# y
# t
# h
# o
# n
# j
# a
# v
# a
# c
# c
# +
# +

# %%
# 리스트의 길이라 함은, 리스트 안의 데이터 개수를 의미
len(text) # len 무지막지하게 잘 쓰임
# Out:
# 4

# %%
name = '정명훈'
age = '28'
region = '천안'
print(name, age, region)
# Out:
# 정명훈 28 천안

# %%
print('Life is too short')
# Out:
# Life is too short

# %%
print('나는 대한민국 사람이며 \n 뭐시기뭐시기 \n ~~~~')
# Out:
# 나는 대한민국 사람이며
#  뭐시기뭐시기
#  ~~~~

# %%
x = '''
aa
aa
aa'''
print(x)
# Out:
# aa
# aa
# aa

# %%
# .split() #인자값을 비우면 엔터, 띄어쓰기를 전부 제거하여 리스트화
x = 'Life is too short'
x.split(' ')
# Out:
# ['Life', 'is', 'too', 'short']

# %%
region= '천안, 아산, 병천, 목천'
region.split(', ')
# Out:
# ['천안', '아산', '병천', '목천']

# %%
# count()
region.count('천')
# Out:
# 3
