# %% [markdown]
# 텍스트 표기 방법, replace, type, for, len(리스트)

# %% [markdown]
# # ''' ''' 문자열 표기에 대해서 복습 필요함!!

# %%
x = 'text'
x = "text"
x = '''text'''

# %%
x = 'python \n java' # \n => 엔터 기능 수행
print(x)
# Out:
# python
# java

# %%
x = 'Life is \'too \'short' # \뒤에 글자를 붙이면 글자를 기능을 제외하고 인식함

# %%
x = 'Life is "too" short' # 같은 따옴표 안에 있을 경우 \를 붙여서 사용하면 연속 사용 가능
x = "Life is 'too' short"

# %%
x
# Out:
# 'Life is "too" short'

# %%
# replace(지정한 글자, 변경할 문자, 횟수)

# %%
text = 'python, java, c, c++'

# %%
text[text.find('c')]
# Out:
# 'c'

# %%
text.replace('c','R', 1)
# Out:
# 'python, java, R, c++'

# %%
text
# Out:
# 'python, java, c, c++'

# %%
text.replace('c', 'R')
# Out:
# 'python, java, R, R++'

# %%
text = '1'
type(text)
text = 1

# %%
a= list(range(3,10,2))
a
# Out:
# [3, 5, 7, 9]

# %%
for i in range(3, 10, 2): # range(시작숫자, 종료숫자, 스텝)
    print(i)
# Out:
# 3
# 5
# 7
# 9

# %%
text = ['python', 'java', 'c', 'c++']

# %%
text
# Out:
# ['python', 'java', 'c', 'c++']

# %%
text = 'string'
text[1]
# Out:
# 't'

# %%
for j in text:
    for i in j: # text[0] = 'python'
        print(i)

# 현재는 python java c c++ 이렇게 출력되는데
# p y t h o n ....이렇게 한줄 띄어쓰기식으로 출력할것
# Out:
# p
# y
# t
# h
# o
# n

# %%
for i in range(2):
    print(i)
# Out:
# 0
# 1

# %%
for i in range(2): # 들여쓰기는 항상 조심할 것
    print(i)
print(1)
# Out:
# 1
# 1

# %%
# PEP 뭔가 지들끼리의 룰이 있음.... 이걸 지키면 모두가 쉽게 알아볼 수 있다!!

# %%
# 리스트의 길이라 함은, 리스트 안의 데이터의 개수를 의미함
len(text)
# Out:
# 4

# %%
# 출력(print) 문제

# %%
# 1. 이름(name)과 나이(age), 거주(region) 지역을 출력하시오

# %%
# 2. 'Life is too short' 를 출력하시오.

# %%
# 3.
# 나는 대한민국 사람이며
# 충청남도에 거주하는
# 홍길동이다!
# 라는 문구를 출력하시오
#  (단 print()를 한번만 사용해서 출력할 것)
# \n 사용금지

# %%
a= '''
나는 대한민국 사람이며
충청남도에 거주하는
최동현이다!
'''

# %%
print(a)
# Out:
# 나는 대한민국 사람이며
# 충청남도에 거주하는
# 최동현이다!

# %%
나는 대한민국 사람이며
충청남도에 거주하는
최동현이다!

# %%
# split 문제

# %%
# 4. 2번 문장을 분리(split)하여
# 'Life', 'is', 'too', 'short'를 출력하시오.

# %%
# 5. region = '천안,아산,병천,목천' 에서
#  region의 지역들을 분리하여 지역별로 출력하시오.

# %%
count()

# %%
# 6. 5번에서 사용한 변수(region)에
# '천'이라는 글자가 들어간 횟수를 출력하시오.
